# %% [markdown]
# Weather Project

# %%
# ============================================================
# Atlanta Weather Data — Import & Analysis Setup
# ============================================================

# Core data wrangling
import pandas as pd
import numpy as np

# File handling / paths
from pathlib import Path

# Date/time utilities (often needed for weather data)
import datetime as dt

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Optional display tweaks for exploratory work
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# ------------------------------------------------------------
# File Import
# ------------------------------------------------------------

file_path = Path("Atlanta Weather 1930-2025.xlsx")

# Load Excel file
df = pd.read_excel(file_path)

# Quick sanity check
print(df.shape)
print(df.head())
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       1 # ============================================================
#       2 # Atlanta Weather Data — Import & Analysis Setup
#       3 # ============================================================
#       4
#       5 # Core data wrangling
# ----> 6 import pandas as pd
#       7 import numpy as np
#       9 # File handling / paths
#
# ModuleNotFoundError: No module named 'pandas'
